# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

from generators import StyleTransferGenerator
from cycle_gan import CycleGAN

# %%
params_json = {
    "run_folder": "c:\\Users\\1\\Desktop\\models_save\\TEST_CycleGAN",
    "input_shape": (128, 128, 3),
    "discriminator_params": {
        "filters_n": 32,
        "layers_n": 3,
        "last_activation": "sigmoid" 
    },

    "generator_params": {
        "filters_n": 32,
        "down_activation": "tanh",
        "up_activation": "tanh",
        "last_activation": "tanh"
    }
}

# %%
cycle_gan = CycleGAN(params_json=params_json)

# %%
print(cycle_gan.discriminator_A.summary())
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 64, 64, 32)     │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_22                │ (None, 64, 64, 32)     │            65 │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
print(cycle_gan.generator_A.summary())
# Out:
# Model: "functional_15"
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(cycle_gan.generator_A.summary())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\models\model.py:256, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#     216 @traceback_utils.filter_traceback
#     217 def summary(
# ...

# %%
generator = StyleTransferGenerator(data_path="c:\\Users\\1\\Desktop\\data_files\\style_transfer_dataset", batch_size=32, target_size=(128, 128))

# %%
data = []
for (batch_number, data_batch) in enumerate(iter(generator)):

    if batch_number == 30:
        break

    data.append(data_batch)

# %%
images = np.concatenate([samples[0] for samples in data], axis=0)
styles = np.concatenate([samples[1] for samples in data], axis=0)
# images = images / 255.0
# styles = styles / 255.0

# %%
images_std = (images - np.mean(images)) / np.std(images)
styles_std = (styles - np.mean(styles)) / np.std(styles)

# %%
plt.style.use("dark_background")
fig, axis = plt.subplots()
axis.imshow(images_std[np.random.randint(0, 100)])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cycle_gan.train_model(images_A=images_std, images_B=styles_std, batch_size=32, epochs=100, epochs_per_save=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x0000025E7E8AB2E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ...
