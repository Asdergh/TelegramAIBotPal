# %%
import numpy as np
from conv_var_ae import VarEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
var_ae = VarEncoder()
# Out:
# WARNING:tensorflow:From C:\Users\1\AppData\Roaming\Python\Python311\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
var_ae.encoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
batch_size = 32
target_size = (128, 128)

# %%
train_image_generator = ImageDataGenerator()
train_image_generator = train_image_generator.flow_from_directory(directory="c:\\Users\\1\\Desktop\\data_files\\human_emotions\\test",
                                          target_size=target_size,
                                          batch_size=batch_size)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
iterator = 0
train_images = []
train_labels = []
while iterator * batch_size < (100 * batch_size):

    batch = next(train_image_generator)
    train_images.append(batch[0])
    train_labels.append(batch[1])

    iterator += 1
train_images = np.concatenate(train_images, axis=0)
train_labels = np.concatenate(train_labels, axis=0)

# %%
run_folder_path = "c:\\Users\\1\\Desktop\\models_save\\AE_save\\test_new_generation_foo"
var_ae.train(train_tensor=train_images, train_labels=train_images, batch_size=32, epochs=100, epoch_per_save=10, run_folder=run_folder_path)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x0000012D20E6E840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
